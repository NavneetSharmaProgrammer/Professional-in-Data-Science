# %% [markdown]
# # String & String Methods in Python
# ## What is a String?
# A string is a sequence of characters enclosed in single (') or double (") quotes.
# #### So String is a collection of characters in python
# ### When will we use string?
# When we have to store characters and whenever we have to store collection of characters Now we will see some strings.
# # To Execute any function in python we have to put parenthesis

# %%
First_name = 'Navneet'
Last_name = "Sharma"

# %%
First_name
# Out:
# 'Navneet'

# %%
Last_name
# Out:
# 'Sharma'

# %%
full_name = (First_name + " " + Last_name)

# %%
full_name
# Out:
# 'Navneet Sharma'

# %% [markdown]
# ### Multiline Strings
# #### Use triple quotes (''' or """) for multiline text.

# %%
message = """This is
a multiline
string"""

# %%
print(message)
# Out:
# This is
# a multiline
# string

# %% [markdown]
# ### String Indexing and Slicing
# #### Indexing starts at 0.
# text[-1]   # 'n' (last character)

# %%
text = "Python"
text[0],text[-1],text[0:2],text[:3],text[3:]
# Out:
# ('P', 'n', 'Py', 'Pyt', 'hon')

# %% [markdown]
# ### String Immutability
# #### Strings cannot be changed after creation.

# %%
text[0] = 'J'  # Error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 text[0] = 'J'  # Error
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Common String Methods

# %% [markdown]
# Common String Methods
# Method	                  Description
# str.lower()	              Converts to lowercase
# str.upper()	              Converts to uppercase
# str.strip()	              Removes leading/trailing spaces
# str.replace(old, new)	  Replaces substring
# str.split(sep)	          Splits string into a list
# str.join(list)	          Joins list into string
# str.find(sub)	          Returns index of first occurrence
# str.count(sub)         	  Counts occurrences of substring
# str.startswith(prefix)	  Checks if string starts with value
# str.endswith(suffix)	  Checks if string ends with value
# str.isdigit()	          Checks if all chars are digits
# str.isalpha()          	  Checks if all chars are letters
# str.isalnum()	          Checks if all chars are letters/digits

# %%
name = "Navneet Sharma"

# %%
name.lower() # Converts to lowercase
# Out:
# 'navneet sharma'

# %%
name.upper() # Converts to uppercase
# Out:
# 'NAVNEET SHARMA'

# %%
name.strip() # Removes leading/trailing spaces
# Out:
# 'Navneet Sharma'

# %%
new_text = name.replace('Navneet', 'Nonu')
print(new_text)
# Out:
# Nonu Sharma

# %% [markdown]
# ## Examples

# %%
"hello".upper()           # 'HELLO'
# Out:
# 'HELLO'

# %%
" Hello ".strip()         # 'Hello'
# Out:
# 'Hello'

# %%
"hello world".split()     # ['hello', 'world']
# Out:
# ['hello', 'world']

# %%
"-".join(["2025", "04", "14"])  # '2025-04-14'
# Out:
# '2025-04-14'

# %%
"python".find("th")       # 2
# Out:
# 2

# %% [markdown]
# ## String Formatting (f-strings)

# %%
name = "Navneet"
age = 210

# %%
f'Hello, {name}. You are {age} years old.'
# Out:
# 'Hello, Navneet. You are 210 years old.'

# %%
name.capitalize()
# Out:
# 'Navneet'

# %% [raw]
# name = "Navneet"

# %%
name.casefold()
# Out:
# 'navneet'
