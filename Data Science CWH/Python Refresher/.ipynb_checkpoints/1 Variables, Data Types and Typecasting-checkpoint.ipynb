# %% [markdown]
# # Python
# ## Is Dynamically typed, Object-oriented Programming Language & it is a general purpose scripting language : used in
# ### Web development
# ### Data Science

# %% [markdown]
# # Variables, Data Types and Typecasting

# %% [markdown]
# ## Variables
# ### - Containers for storing data values.
# ### - No need to declare data type explicitly.
# #### means that the programming language automatically determines the variable's data type based on the value assigned to it, a process known as type inference or implicit typing.

# %% [markdown]
# name = "Alice"
# age = 25
# is_student = True

# %% [raw]
#  Data Types
#  Type	     Example	      Description
#  int	     10, -5	          Integer numbers
#  float	     3.14, -0.5	      Decimal numbers
#  str	     "hello"	      Text (string)
#  bool	     True, False	  Boolean values
#  list	     [1, 2, 3]	      Ordered, mutable collection
#  tuple	     (1, 2, 3)	      Ordered, immutable collection
#  dict	     {"a": 1}	      Key-value pairs

# %% [raw]
# Typecasting (Type Conversion)
# Convert data from one type to another using built-in functions:
# # str to int
# x = int("10")      # 10
#
# # int to str
# y = str(25)        # "25"
#
# # float to int
# z = int(3.9)       # 3 (truncates, not rounds)
#
# # list from string
# lst = list("abc")  # ['a', 'b', 'c']

# %% [raw]
# Quick Tips
# Use type(variable) to check a variable’s data type.
#
# Typecasting errors can happen if the value isn't compatible:

# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "Navneet"

# %%
print("Hello World") # This will print hello world on the screen
# Out:
# Hello World

# %%
# This is a comment

# %%
print(type(a)) # Find Type
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %% [markdown]
# ## Data Types & Variables
# #### Python has dynamic typing, meaning you don't need to declare variable types.

# %%
x = 10              # Integer
y = 3.14            # Float
name = "Jack"       # String
is_vjackd = True    # Boolean

# %%
type(name)
# Out:
# str

# %%
a = "4566"
b = "5677"

# %%
print(a+b)
# Out:
# 45665677

# %%
int(a)+int(b)
# Out:
# 10243
