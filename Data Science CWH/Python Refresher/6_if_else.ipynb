# %% [markdown]
# indentation one tab or 4 spaces

# %%
a = 400

# %%
if(a>53):
    print("Greater")
else:
    print("Smaller")
# Out:
# Greater

# %% [markdown]
# if else ladder

# %%
a = 29
if a>50:
    print("Greater than 50")
elif(a>40):
    print("Greater than 40")
elif(a>30):
    print("Greater than 30")
else:
    print("Done")
# Out:
# Done

# %%
def avg(a,b):
    return (a+b)/2

# %%
avg(2,4)
# Out:
# 3.0
