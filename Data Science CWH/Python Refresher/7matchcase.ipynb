# %% [markdown]
# Match

# %%
code = 2000

# %%
match code:
    case 200:
        print("Response Ok")
        print("Good Job")
    case 400:
        print("Bad Response")
    case 404:
        print("Not found")
    case _:
        print("Nothing Matched")
print("End of Program")
# Out:
# Nothing Matched
# End of Program
