# %%
s = "Navneet"

# %%
s.upper()
# Out:
# 'NAVNEET'

# %%
s
# Out:
# 'Navneet'

# %%
name = "snoop"
age = 8
print("My name is {} and I am {} months old.".format(name,age))
# Out:
# My name is snoop and I am 8 months old.

# %%
print(f"My name is {name} and I am {age} months old.")
# Out:
# My name is snoop and I am 8 months old.

# %%
print(f"{'Python':<40}") 
print(f"{'Python':>40}") 
print(f"{'Python':^40}")
# Out:
# Python
#                                   Python
#                  Python
