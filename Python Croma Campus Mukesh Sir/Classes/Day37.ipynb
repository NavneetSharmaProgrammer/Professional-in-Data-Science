# %% [markdown]
# ## Numpy : Numerical in Python

# %% [markdown]
# #### Numpy is a powerful Library for mathematical calculations

# %% [markdown]
# ##### We will use numpy to create arrays

# %% [markdown]
# ##### Array :- Array is a collection of homogeneous (Same Data Types) elements
# ##### - It works on contiguous memory ( list works on nodes
# #####
# ##### - List is faster than the erray in <b> insertion and deletion <b>
# ##### - Array has a static memory

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy

# %%
#
